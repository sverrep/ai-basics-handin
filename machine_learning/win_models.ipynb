# %%
import pandas as pd
from numpy import where
from numpy import unique
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn.cluster import KMeans
from matplotlib import pyplot
from pymongo import MongoClient
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
import joblib

client = MongoClient("mongodb+srv://testadmin:testadmin@dbtest.37wj1.mongodb.net/dbtest?retryWrites=true&w=majority")
db = client.dota2

def createCarryWinModel():

    collection = db.promatches_players.find({'ml_lane_role': 1, }, {'_id':0})
    df = pd.DataFrame(list(collection))
    y = df['win']
    x = df[['kills', 'deaths', 'assists', 'gpm', 'xpm', 'duration']].values


    logreg = LogisticRegression(random_state=0, max_iter=1000).fit(x, y)

    modelfile = 'models/carry_win.sav'
    joblib.dump(logreg, modelfile)

def createMidlaneWinModel():
    
    collection = db.promatches_players.find({'ml_lane_role': 2, }, {'_id':0})
    df = pd.DataFrame(list(collection))
    y = df['win']
    x = df[['kills', 'deaths', 'assists', 'gpm', 'xpm', 'duration']].values

    logreg = LogisticRegression(random_state=0, max_iter=1000).fit(x, y)

    modelfile = 'models/mid_win.sav'
    joblib.dump(logreg, modelfile)

def createOffWinModel():

    collection = db.promatches_players.find({'ml_lane_role': 3, }, {'_id':0})
    df = pd.DataFrame(list(collection))
    y = df['win']
    x = df[['kills', 'deaths', 'assists', 'gpm', 'xpm', 'duration']].values


    logreg = LogisticRegression(random_state=0, max_iter=1000).fit(x, y)

    modelfile = 'models/off_win.sav'
    joblib.dump(logreg, modelfile)


def createSoftSupWinModel():
    collection_of_four = db.promatches_players.find({'ml_lane_role': 4, }, {'_id':0})
    dffour = pd.DataFrame(list(collection_of_four))
    
    y = dffour['win']
    x = dffour[['kills', 'deaths', 'assists', 'gpm', 'xpm', 'duration', 'obs_placed', 'obs_killed']].values

    logregfour = LogisticRegression(random_state=0, max_iter=1000).fit(x, y)

    modelfile = 'models/softsup_win.sav'
    joblib.dump(logregfour, modelfile)

def createHardSupWinModel():
    collection_of_five = db.promatches_players.find({'ml_lane_role': 5, }, {'_id':0})
    dffive = pd.DataFrame(list(collection_of_five))
    
    y = dffive['win']
    x = dffive[['kills', 'assists', 'gpm', 'xpm', 'duration', 'obs_placed', 'obs_killed']].values

    logregfive = LogisticRegression(random_state=0, max_iter=1000).fit(x, y)

    modelfile = 'models/hardsup_win.sav'
    joblib.dump(logregfive, modelfile)
    

def createAllWinModels():
    createCarryWinModel()
    createMidlaneWinModel()
    createOffWinModel()
    createSoftSupWinModel()
    createHardSupWinModel()

createAllWinModels()
